# %%
import graph_module as gm
import pandas as pd
from data_utils import group_medals, filter_medal_entries
import plotly_express as px

# %%
df = pd.read_csv("athlete_events.csv")

# %%
gm.norway_age_histogram(df)

# %%
gm.countries_with_most_medals_in_sport(df, sport="Football")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 gm.countries_with_most_medals_in_sport(df, sport="Football")
#
# File ~/Desktop/projekt-os/graph_module.py:36, in countries_with_most_medals_in_sport(df, sport)
#      33 medal_counts = medal_counts.sort_values(by="Total", ascending=False)
#      34 medal_counts = medal_counts.iloc[:20]
# ---> 36 fig = px.bar(medal_counts, x=medal_counts.index, y=medal_counts["Total"], title=sport, color=medal_counts.index, showlegend=False)
#      37 return fig
#
# TypeError: bar() got an unexpected keyword argument 'showlegend'

# %%
gm.most_medals_by_country(df)

# %%
gm.norway_top_sports(df)

# %%
gm.sport_age_dist_graph(df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 gm.sport_age_dist_graph(df)
#
# AttributeError: module 'graph_module' has no attribute 'sport_age_dist_graph'

# %%
gm.medal_distribution_by_country(df, sport="Alpine Skiing") # Pass in a sport to change what sport the graph shows

# %%
gm.norway_medals_per_year_graph(df)

# %%
gm.subplot_medal_distribution(df, "Alpine Skiing", "Football", "Gymnastics","Shooting")
