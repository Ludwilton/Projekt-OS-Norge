# %%
import pandas as pd
import matplotlib.pyplot as plt 

athlete_events = pd.read_csv("../athlete_events.csv")
athlete_events.head(10)
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
# 5   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
# 6   5  Christine Jacoba Aaftink   F  25.0   185.0    82.0     Netherlands
# 7   5  Christine Jacoba Aaftink   F  25.0   185.0    82.0     Netherlands
# 8   5  Christine Jacoba Aaftink   F  27.0   185.0    82.0     Netherlands
# 9   5  Christine Jacoba Aaftink   F  27.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season         City          Sport  \
# 0  CHN  1992 Summer  1992  Summer    Barcelona     Basketball
# ...

# %%
# A)
athlete_events["NOC"].nunique()
# Out:
# 230

# %%
# B)
athlete_events["NOC"].unique()
# Out:
# array(['CHN', 'DEN', 'NED', 'USA', 'FIN', 'NOR', 'ROU', 'EST', 'FRA',
#        'MAR', 'ESP', 'EGY', 'IRI', 'BUL', 'ITA', 'CHA', 'AZE', 'SUD',
#        'RUS', 'ARG', 'CUB', 'BLR', 'GRE', 'CMR', 'TUR', 'CHI', 'MEX',
#        'URS', 'NCA', 'HUN', 'NGR', 'ALG', 'KUW', 'BRN', 'PAK', 'IRQ',
#        'UAR', 'LIB', 'QAT', 'MAS', 'GER', 'CAN', 'IRL', 'AUS', 'RSA',
#        'ERI', 'TAN', 'JOR', 'TUN', 'LBA', 'BEL', 'DJI', 'PLE', 'COM',
#        'KAZ', 'BRU', 'IND', 'KSA', 'SYR', 'MDV', 'ETH', 'UAE', 'YAR',
#        'INA', 'PHI', 'SGP', 'UZB', 'KGZ', 'TJK', 'EUN', 'JPN', 'CGO',
#        'SUI', 'BRA', 'FRG', 'GDR', 'MON', 'ISR', 'URU', 'SWE', 'ISV',
#        'SRI', 'ARM', 'CIV', 'KEN', 'BEN', 'UKR', 'GBR', 'GHA', 'SOM',
#        'LAT', 'NIG', 'MLI', 'AFG', 'POL', 'CRC', 'PAN', 'GEO', 'SLO',
#        'CRO', 'GUY', 'NZL', 'POR', 'PAR', 'ANG', 'VEN', 'COL', 'BAN',
#        'PER', 'ESA', 'PUR', 'UGA', 'HON', 'ECU', 'TKM', 'MRI', 'SEY',
# ...

# %%
athlete_events.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %%
athlete_events["Event"].unique()
# Out:
# array(["Basketball Men's Basketball", "Judo Men's Extra-Lightweight",
#        "Football Men's Football", "Tug-Of-War Men's Tug-Of-War",
#        "Speed Skating Women's 500 metres",
#        "Speed Skating Women's 1,000 metres",
#        "Cross Country Skiing Men's 10 kilometres",
#        "Cross Country Skiing Men's 50 kilometres",
#        "Cross Country Skiing Men's 10/15 kilometres Pursuit",
#        "Cross Country Skiing Men's 4 x 10 kilometres Relay",
#        "Cross Country Skiing Men's 30 kilometres",
#        "Athletics Women's 100 metres",
#        "Athletics Women's 4 x 100 metres Relay",
#        "Ice Hockey Men's Ice Hockey",
#        "Swimming Men's 400 metres Freestyle", "Badminton Men's Singles",
#        "Sailing Women's Windsurfer",
#        "Biathlon Women's 7.5 kilometres Sprint",
#        "Swimming Men's 200 metres Breaststroke",
#        "Swimming Men's 400 metres Breaststroke",
#        "Gymnastics Men's Individual All-Around",
# ...

# %%
athlete_events["Medal"].nunique()
# Out:
# 3

# %%
# E)

medelvärde = athlete_events["Age"].mean()

median = athlete_events["Age"].median()

min = athlete_events["Age"].min()

max = athlete_events["Age"].max()

standardavikelse = athlete_events["Age"].std()

print (f"{medelvärde:.2f}")
print (median)
print (min)
print (max)
print (f"{standardavikelse:.2f}")
# Out:
# 25.56
# 24.0
# 10.0
# 97.0
# 6.39

# %%
medalj_data = athlete_events.dropna(subset=["Medal"])


medaljer_per_land = medalj_data.groupby("NOC")["Medal"].count()


topp_10_lander = medaljer_per_land.nlargest(10)


plt.figure(figsize=(10, 6))
topp_10_lander.plot(kind="bar", color="skyblue")
plt.suptitle("Topp 10 Länder med Flest Medaljer")
plt.xlabel("Land")
plt.ylabel("Antal Medaljer")
plt.xticks(rotation=45)
plt.show()

# %%
sex_value_count= athlete_events["Sex"].value_counts()

plt.figure(figsize=(8, 8))
sex_value_count.plot(kind="pie", autopct="%1.1f%%", startangle=50, colors=["skyblue", "pink"])
plt.title =("Könsfördelning")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import hashlib as hl

df =pd.read_csv("../athlete_events.csv", usecols=["Name", "Sex",	"Age", "Height",	"Weight",	"Team",	"NOC",	"Games",	"Year",	"Season",	"City",	"Sport",	"Event",	"Medal"])
df.head()
# Out:
#                        Name Sex   Age  Height  Weight            Team  NOC  \
# 0                 A Dijiang   M  24.0   180.0    80.0           China  CHN
# 1                  A Lamusi   M  23.0   170.0    60.0           China  CHN
# 2       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark  DEN
# 3      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden  DEN
# 4  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands  NED
#
#          Games  Year  Season       City          Sport  \
# 0  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  2012 Summer  2012  Summer     London           Judo
# 2  1920 Summer  1920  Summer  Antwerpen       Football
# 3  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# 2           Football Men's Football   NaN
# ...

# %%
import hashlib as hl
import pandas as pd


df = pd.read_csv("../athlete_events.csv", usecols=["Name", "Sex", "Age", "Height", "Weight", "Team", "NOC", "Games", "Year", "Season", "City", "Sport", "Event", "Medal"])


df["Name"] = df["Name"].astype(str).apply(lambda name: hl.sha256(name.encode()).hexdigest())


df.head(10)
# Out:
#                                                 Name Sex   Age  Height  \
# 0  3a4eef48434c66b3f14ab0221f6762d0ef7c6135ab2790...   M  24.0   180.0
# 1  a6430cc6630934275dc6283f7e97e9625e6587cdddec7a...   M  23.0   170.0
# 2  9c198b205332c2c8e1542e0f9534b9e270780a41d978ec...   M  24.0     NaN
# 3  0a477bb1c5ad39716f9c775e54d18d16aa8b37ada55548...   M  34.0     NaN
# 4  5b7be356aa28178096dc6747f0b8e4e393eaceb5f95310...   F  21.0   185.0
# 5  5b7be356aa28178096dc6747f0b8e4e393eaceb5f95310...   F  21.0   185.0
# 6  5b7be356aa28178096dc6747f0b8e4e393eaceb5f95310...   F  25.0   185.0
# 7  5b7be356aa28178096dc6747f0b8e4e393eaceb5f95310...   F  25.0   185.0
# 8  5b7be356aa28178096dc6747f0b8e4e393eaceb5f95310...   F  27.0   185.0
# 9  5b7be356aa28178096dc6747f0b8e4e393eaceb5f95310...   F  27.0   185.0
#
#    Weight            Team  NOC        Games  Year  Season         City  \
# 0    80.0           China  CHN  1992 Summer  1992  Summer    Barcelona
# ...

# %%
import hashlib as hl

NORWAY =pd.read_csv("../athlete_events.csv", usecols=["Name", "Sex",	"Age", "Height",	"Weight",	"Team",	"NOC",	"Games",	"Year",	"Season",	"City",	"Sport",	"Event",	"Medal"])
NORWAY2= NORWAY[NORWAY["NOC"] == "NOR"]
NORWAY2.dropna(subset=["Medal"])
# Out:
#                                      Name Sex   Age  Height  Weight    Team  \
# 60                     Kjetil Andr Aamodt   M  20.0   176.0    85.0  Norway
# 61                     Kjetil Andr Aamodt   M  20.0   176.0    85.0  Norway
# 63                     Kjetil Andr Aamodt   M  22.0   176.0    85.0  Norway
# 64                     Kjetil Andr Aamodt   M  22.0   176.0    85.0  Norway
# 67                     Kjetil Andr Aamodt   M  22.0   176.0    85.0  Norway
# ...                                   ...  ..   ...     ...     ...     ...
# 260346              Lauritz Wigand-Larsen   M  24.0     NaN     NaN  Norway
# 260491                     Per Olav Wiken   M  31.0   183.0    80.0  Norway
# 262378  Marit Elisabeth Wold-Mikkelsplass   F  22.0   172.0    57.0  Norway
# 262380  Marit Elisabeth Wold-Mikkelsplass   F  28.0   172.0    57.0  Norway
# 262385  Marit Elisabeth Wold-Mikkelsplass   F  32.0   172.0    57.0  Norway
#
# ...

# %%
import pandas as pd


df = pd.read_csv("../athlete_events.csv", usecols=["Name", "Sex", "Age", "Height", "Weight", "Team", "NOC", "Games", "Year", "Season", "City", "Sport", "Event", "Medal"])


norge_medaljer = df[(df["NOC"] == "NOR") & df["Medal"].notna()]

norge_medaljer=norge_medaljer.drop_duplicates(subset=["Event", "Games", "Team", "Medal"])
medaljer_per_sport = norge_medaljer.groupby("Sport")["Medal"].count()

medaljer_per_sport = medaljer_per_sport.sort_values(ascending=False)
medaljer_per_sport
# Out:
# Sport
# Cross Country Skiing    97
# Speed Skating           80
# Biathlon                35
# Shooting                33
# Sailing                 31
# Nordic Combined         30
# Ski Jumping             30
# Alpine Skiing           29
# Athletics               20
# Rowing                  17
# Canoeing                14
# Freestyle Skiing         8
# Wrestling                8
# Handball                 6
# Figure Skating           6
# Gymnastics               5
# Boxing                   5
# Cycling                  4
# Snowboarding             4
# Curling                  3
# Football                 3
# Swimming                 2
# Taekwondo                2
# Art Competitions         1
# Fencing                  1
# Equestrianism            1
# Tennis                   1
# Weightlifting            1
# Name: Medal, dtype: int64

# %%
plt.figure(figsize=(15, 5))
medaljer_per_sport.plot(kind="bar", color="skyblue")
plt.title("Sporter där Norge har vunnit flest medaljer")
plt.xlabel("Sport")
plt.ylabel("Antal Medaljer")
plt.xticks(rotation=50)
plt.tight_layout()  
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[136], line 3
#       1 plt.figure(figsize=(15, 5))
#       2 medaljer_per_sport.plot(kind="bar", color="skyblue")
# ----> 3 plt.title("Sporter där Norge har vunnit flest medaljer")
#       4 plt.xlabel("Sport")
#       5 plt.ylabel("Antal Medaljer")
#
# TypeError: 'str' object is not callable
