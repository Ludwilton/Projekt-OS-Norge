# %% [markdown]
# # Explorativ datanalys över hela datasettet

# %%
import pandas as pd
import seaborn as sns
import plotly_express as px
import matplotlib.pyplot as plt
import sys
sys.path.append("..") # Adds higher directory to python modules path.
import data_utils

# %%
df = pd.read_csv("../athlete_events.csv")
df
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %% [markdown]
# a.

# %%
# amount of participating countries

print(f"Amount of participating countries all time: {len(df['NOC'].unique())}")
# Out:
# Amount of participating countries all time: 230

# %% [markdown]
# b.

# %%
for i in (df["NOC"].unique()):
    print(f"\n {i}")
# Out:
#  CHN
#
#  DEN
#
#  NED
#
#  USA
#
#  FIN
#
#  NOR
#
#  ROU
#
#  EST
#
#  FRA
#
#  MAR
#
#  ESP
#
#  EGY
#
#  IRI
#
#  BUL
#
#  ITA
#
#  CHA
#
#  AZE
#
#  SUD
#
#  RUS
#
#  ARG
#
#  CUB
#
#  BLR
#
#  GRE
#
#  CMR
#
#  TUR
#
#  CHI
#
#  MEX
#
#  URS
#
#  NCA
#
#  HUN
#
#  NGR
#
#  ALG
#
#  KUW
#
#  BRN
#
#  PAK
#
#  IRQ
#
#  UAR
#
#  LIB
#
#  QAT
#
#  MAS
#
#  GER
#
#  CAN
#
#  IRL
#
#  AUS
#
#  RSA
#
#  ERI
#
#  TAN
#
#  JOR
#
#  TUN
#
#  LBA
#
#  BEL
#
#  DJI
#
#  PLE
#
#  COM
#
#  KAZ
#
#  BRU
#
#  IND
#
#  KSA
#
#  SYR
#
#  MDV
#
#  ETH
#
#  UAE
#
#  YAR
#
#  INA
#
#  PHI
#
#  SGP
#
#  UZB
#
#  KGZ
#
#  TJK
#
#  EUN
#
#  JPN
#
#  CGO
#
#  SUI
#
#  BRA
#
#  FRG
#
#  GDR
#
#  MON
#
#  ISR
#
#  URU
#
#  SWE
#
#  ISV
#
#  SRI
#
#  ARM
#
#  CIV
#
#  KEN
#
#  BEN
#
#  UKR
#
#  GBR
#
#  GHA
#
#  SOM
#
#  LAT
#
#  NIG
#
#  MLI
#
#  AFG
#
#  POL
#
#  CRC
#
#  PAN
#
#  GEO
#
#  SLO
#
#  CRO
#
#  GUY
#
#  NZL
#
#  POR
#
#  PAR
#
#  ANG
#
#  VEN
#
#  COL
#
#  BAN
#
#  PER
#
#  ESA
#
#  PUR
#
# ...

# %% [markdown]
# c.

# %%
sports = df["Sport"]
sports.unique()
# Out:
# array(['Basketball', 'Judo', 'Football', 'Tug-Of-War', 'Speed Skating',
#        'Cross Country Skiing', 'Athletics', 'Ice Hockey', 'Swimming',
#        'Badminton', 'Sailing', 'Biathlon', 'Gymnastics',
#        'Art Competitions', 'Alpine Skiing', 'Handball', 'Weightlifting',
#        'Wrestling', 'Luge', 'Water Polo', 'Hockey', 'Rowing', 'Bobsleigh',
#        'Fencing', 'Equestrianism', 'Shooting', 'Boxing', 'Taekwondo',
#        'Cycling', 'Diving', 'Canoeing', 'Tennis', 'Modern Pentathlon',
#        'Figure Skating', 'Golf', 'Softball', 'Archery', 'Volleyball',
#        'Synchronized Swimming', 'Table Tennis', 'Nordic Combined',
#        'Baseball', 'Rhythmic Gymnastics', 'Freestyle Skiing',
#        'Rugby Sevens', 'Trampolining', 'Beach Volleyball', 'Triathlon',
#        'Ski Jumping', 'Curling', 'Snowboarding', 'Rugby',
#        'Short Track Speed Skating', 'Skeleton', 'Lacrosse', 'Polo',
#        'Cricket', 'Racquets', 'Motorboating', 'Military Ski Patrol',
# ...

# %% [markdown]
# d.

# %%
print(*df["Medal"].dropna().unique())
# Out:
# Gold Bronze Silver

# %% [markdown]
# e.

# %%
print("Age column statistics")
df["Age"].describe()
# Out:
# Age column statistics
# count    261642.000000
# mean         25.556898
# std           6.393561
# min          10.000000
# 25%          21.000000
# 50%          24.000000
# 75%          28.000000
# max          97.000000
# Name: Age, dtype: float64

# %% [markdown]
# f.

# %% [markdown]
# g.

# %%
ax = sns.histplot(data=df, x="Sex",shrink=.8, hue="Sex")
for container in ax.containers: # pop info labels on bars
    ax.bar_label(container)

# %%
no_df = df[df["NOC"]=="NOR"]

# %%
no_df = df[df["NOC"]=="NOR"]
plt.figure(figsize=(10,6))
ax = sns.barplot(data=no_df, x="Year",y="Age", hue="Sex")
plt.xticks(rotation=50)
plt.show()

# %%
no_df
# Out:
#             ID                        Name Sex   Age  Height  Weight    Team  \
# 59          20          Kjetil Andr Aamodt   M  20.0   176.0    85.0  Norway
# 60          20          Kjetil Andr Aamodt   M  20.0   176.0    85.0  Norway
# 61          20          Kjetil Andr Aamodt   M  20.0   176.0    85.0  Norway
# 62          20          Kjetil Andr Aamodt   M  20.0   176.0    85.0  Norway
# 63          20          Kjetil Andr Aamodt   M  22.0   176.0    85.0  Norway
# ...        ...                         ...  ..   ...     ...     ...     ...
# 270398  135259       Schirin Zorriasateiny   F  20.0   167.0    55.0  Norway
# 270674  135365  Mats Andr Zuccarello-Aasen   M  22.0   171.0    74.0  Norway
# 270675  135365  Mats Andr Zuccarello-Aasen   M  26.0   171.0    74.0  Norway
# 271017  135524      Nicolaus "Nic" Zwetnow   M  31.0   181.0    70.0  Norway
# 271018  135524      Nicolaus "Nic" Zwetnow   M  35.0   181.0    70.0  Norway
#
# ...

# %%
medals_df = no_df[no_df["Medal"].notnull()]



unique_medals_df = medals_df.drop_duplicates(subset=["Event", "Games", "Team","Medal"])
unique_medals_df
# Out:
#             ID                               Name Sex   Age  Height  Weight  \
# 60          20                 Kjetil Andr Aamodt   M  20.0   176.0    85.0
# 61          20                 Kjetil Andr Aamodt   M  20.0   176.0    85.0
# 63          20                 Kjetil Andr Aamodt   M  22.0   176.0    85.0
# 64          20                 Kjetil Andr Aamodt   M  22.0   176.0    85.0
# 67          20                 Kjetil Andr Aamodt   M  22.0   176.0    85.0
# ...        ...                                ...  ..   ...     ...     ...
# 253109  126745                   Hans Vinjarengen   M  26.0   183.0     NaN
# 254477  127396              Otto Wessel von Porat   M  20.0   193.0    92.0
# 255714  128026                        Kre Walberg   M  19.0   173.0     NaN
# 258904  129619                         Heidi Weng   F  22.0   163.0     NaN
# 262380  131280  Marit Elisabeth Wold-Mikkelsplass   F  28.0   172.0    57.0
#
# ...

# %%
medals_per_year = unique_medals_df.groupby(["Year","Sex"])["Medal"].count().reset_index()

plt.figure(figsize=(10, 6))
sns.barplot(data=medals_per_year,x="Year", y="Medal", hue="Sex")
plt.title("number of olympic medals per year by each gender")
plt.xticks(rotation=90)
plt.show()
unique_medals_df
# Out:
#             ID                               Name Sex   Age  Height  Weight  \
# 60          20                 Kjetil Andr Aamodt   M  20.0   176.0    85.0
# 61          20                 Kjetil Andr Aamodt   M  20.0   176.0    85.0
# 63          20                 Kjetil Andr Aamodt   M  22.0   176.0    85.0
# 64          20                 Kjetil Andr Aamodt   M  22.0   176.0    85.0
# 67          20                 Kjetil Andr Aamodt   M  22.0   176.0    85.0
# ...        ...                                ...  ..   ...     ...     ...
# 253109  126745                   Hans Vinjarengen   M  26.0   183.0     NaN
# 254477  127396              Otto Wessel von Porat   M  20.0   193.0    92.0
# 255714  128026                        Kre Walberg   M  19.0   173.0     NaN
# 258904  129619                         Heidi Weng   F  22.0   163.0     NaN
# 262380  131280  Marit Elisabeth Wold-Mikkelsplass   F  28.0   172.0    57.0
#
# ...

# %% [markdown]
# h.

# %%
medals_by_sport = unique_medals_df.groupby(["Sport","Sex"])["Medal"].count().reset_index()

plt.figure(figsize=(10, 6))
sns.barplot(data=medals_by_sport,x="Sport", y="Medal", hue="Sex")
plt.title("number of olympic medals per sport by each gender")
plt.xticks(rotation=80)
plt.show()
medals_by_sport
# Out:
#                    Sport Sex  Medal
# 0          Alpine Skiing   F      1
# 1          Alpine Skiing   M     28
# 2       Art Competitions   M      1
# 3              Athletics   F      5
# 4              Athletics   M     15
# 5               Biathlon   F      8
# 6               Biathlon   M     27
# 7                 Boxing   M      5
# 8               Canoeing   M     14
# 9   Cross Country Skiing   F     36
# 10  Cross Country Skiing   M     61
# 11               Curling   M      3
# 12               Cycling   F      1
# 13               Cycling   M      3
# 14         Equestrianism   M      1
# 15               Fencing   M      1
# 16        Figure Skating   F      4
# 17        Figure Skating   M      2
# 18              Football   F      2
# 19              Football   M      1
# 20      Freestyle Skiing   F      7
# 21      Freestyle Skiing   M      1
# 22            Gymnastics   M      5
# 23              Handball   F      6
# 24       Nordic Combined   M     30
# ...

# %% [markdown]
# i.

# %%
unique_participants= no_df.drop_duplicates(subset=["ID"])


plt.figure(figsize=(10, 30))
ax = sns.boxplot(data=unique_participants,y="Sport", x="Age", hue="Sex")
plt.grid()
plt.title("Age distribution in each sport by gender")
plt.show()

# %%
plt.figure(figsize=(10, 20))
ax = sns.boxplot(data=unique_participants,y="Sport", x="Age")
plt.grid()
plt.title("Age distribution in each sport")
plt.show()

# %%
# Alpine skiing
# Gymnastics
# Football
# Shooting


all_unique_participants = df.drop_duplicates(subset=["ID"])
age_dist_sports = all_unique_participants[all_unique_participants["Sport"].isin(["Alpine Skiing", "Gymnastics", "Football", "Shooting"])]

# %%
plt.figure(figsize=(10, 5))
ax = sns.boxplot(data=age_dist_sports,y="Age", x="Sport", hue="Sex")
plt.grid()
plt.title("Age distribution in each sport")
plt.tight_layout()
plt.show()

# %%
medals_by_country = age_dist_sports.groupby(["NOC", "Sport"])["Medal"].count().reset_index()
medals_by_country

all_medals_df = medals_by_country[medals_by_country["Medal"] > 0]

skiing_medals = all_medals_df[all_medals_df["Sport"]== "Alpine Skiing"].sort_values(by="Medal", ascending=False)
football_medals = all_medals_df[all_medals_df["Sport"]== "Football"].sort_values(by="Medal", ascending=False)
shooting_medals = all_medals_df[all_medals_df["Sport"]== "Shooting"].sort_values(by="Medal", ascending=False)
gymnastics_medals = all_medals_df[all_medals_df["Sport"]== "Gymnastics"].sort_values(by="Medal", ascending=False)

# %%
plt.figure(figsize=(10,5))
sns.barplot(skiing_medals, x="NOC", y="Medal", hue="NOC")
plt.title("Alpine Skiing medals")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.barplot(shooting_medals, x="NOC", y="Medal", hue="NOC")
plt.title("Shooting medals")
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.barplot(football_medals, x="NOC", y="Medal", hue="NOC")
plt.title("Football Medals")
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.barplot(gymnastics_medals, x="NOC", y="Medal", hue="NOC")
plt.title("Gymnastics Medals")
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
df = pd.read_csv("../athlete_events.csv")

df = df.dropna(subset=["Age"])
df_filt = df.drop_duplicates(subset=["Sport", "Games", "ID"])
sports = ["Gymnastics", "Shooting", "Football","Alpine Skiing"]
df_filt = df_filt[df_filt["Sport"].isin(sports)]

fig = px.box(
    df_filt,
    x="Sport",
    y="Age",
    title="Medelålder per sport",
    labels={"Age": "Medelålder (år)", "Sport": "Sport"},
    color="Sport", 
)


fig.update_layout(
    xaxis_tickangle=-90,
    xaxis_title="Sport",
    yaxis_title="Medelålder (år)",
    title_font_size=20
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/Desktop/projekt-os/.venv/lib/python3.12/site-packages/IPython/core/formatters.py:925, in IPythonDisplayFormatter.__call__(self, obj)
#     923 method = get_real_method(obj, self.print_method)
#     924 if method is not None:
# --> 925     method()
#     926     return True
#
# File ~/Desktop/projekt-os/.venv/lib/python3.12/site-packages/plotly/basedatatypes.py:832, in BaseFigure._ipython_display_(self)
#     829 import plotly.io as pio
#     831 if pio.renderers.render_on_display and pio.renderers.default:
# --> 832     pio.show(self)
#     833 else:
#     834     print(repr(self))
#
# File ~/Desktop/projekt-os/.venv/lib/python3.12/site-packages/plotly/io/_renderers.py:394, in show(fig, renderer, validate, **kwargs)
#     389         raise ValueError(
# ...
